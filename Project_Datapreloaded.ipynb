# %%
from google.colab import drive
from google.colab import files 
import os

drive.mount("/content/gdrive")
print(os.getcwd())
os.chdir("/content/gdrive/My Drive/AML2021")
print(os.getcwd())
# Out:
# Mounted at /content/gdrive
# /content
# /content/gdrive/.shortcut-targets-by-id/1_nr6od538RmnZRE1gB6vQYFsrHaUgS19/AML2021

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

from tensorflow.keras import backend, optimizers, models, applications, metrics
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Input
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger, TensorBoard
import tensorflow.keras.utils as utils

# %%
x_train = np.load("x_train.npy")
y_train = np.load("y_train.npy")

print(x_train.shape, y_train.shape)
# Out:
# (16324, 299, 299, 3) (16324, 2)

# %%
# Adapt Constants
date = time.strftime("%d:%m:%Y, %H:%M:%S")
MODEL_NAME = f"ResNet101-{date}"
os.makedirs(f'models/{MODEL_NAME}', exist_ok = True) 
INPUT_SHAPE = (299, 299, 3)
NUM_CLASSES = 2
INITIAL_EPOCH = 0
NUM_EPOCHS = 120
OPTIMIZER = optimizers.SGD(learning_rate=0.1, momentum=0.9, nesterov=False)
BATCH_SIZE = 16

LRS = ReduceLROnPlateau(monitor='val_auroc', factor=0.1, patience=10, verbose=1, mode='auto', min_delta=0.0001)
ES = EarlyStopping(monitor='val_auroc', min_delta=0.0001, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=False)


MC = ModelCheckpoint(f'models/{MODEL_NAME}/latest-{MODEL_NAME}.hdf5', monitor='val_auroc', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq="epoch")
MC_BEST = ModelCheckpoint(f'models/{MODEL_NAME}/best-{MODEL_NAME}.hdf5', monitor='val_auroc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq="epoch")
LOG = CSVLogger(f'models/{MODEL_NAME}/{MODEL_NAME}.log')
TB = TensorBoard(log_dir=f'models/{MODEL_NAME}/logs')

METRICS = [metrics.AUC(name='auroc', curve='ROC'),
           metrics.Accuracy(name='accuracy'),
           metrics.Precision(name='precision'),
           metrics.Recall(name='recall')
           ]

# Load data
assert(backend.image_data_format()=='channels_last')

# Model: preprocess, base model, top layer/classifier
i = Input(shape=INPUT_SHAPE)
x = applications.resnet.preprocess_input(i)

base_model = applications.ResNet101(include_top=False, weights="imagenet", input_shape=INPUT_SHAPE)
x = base_model(x)

x = GlobalAveragePooling2D(name='avg_pool')(x)
o = Dense(NUM_CLASSES, activation='softmax', name=f'fc{NUM_CLASSES}')(x)

model = models.Model(inputs=i, outputs=o)

# Train Model
if INITIAL_EPOCH != 0:
	model = models.load_model(f'models/{MODEL_NAME}/latest-{MODEL_NAME}.hdf5', compile=True)
else:
  model.compile(optimizer=OPTIMIZER, loss='categorical_crossentropy', metrics=METRICS)

model.fit(x=x_train, y=y_train, batch_size=BATCH_SIZE, validation_split = 0.2, callbacks = [MC, MC_BEST, LRS, ES, LOG, TB], epochs = NUM_EPOCHS, initial_epoch = INITIAL_EPOCH)

# Eval Model
x_test = np.load("x_test.npy")
y_test = np.load("y_test.npy")

model = models.load_model(f'models/{MODEL_NAME}/latest-{MODEL_NAME}.hdf5', compile=True)
out = model.evaluate(test_generator, batch_size=BATCH_SIZE, verbose=1)

# Save Results
with open("results.txt","a+") as f:
  f.write(f"{MODEL_NAME} test_loss: {out[0]}, test_auroc: {out[1]}, test_acc: {out[2]}, test_prec: {out[3]}, test_rec: {out[4]}, test_f1: {2* ((out[3]*out[4]) / (out[3]+out[4]))}\n")
print(f"wrote \"{MODEL_NAME} test_loss: {out[0]}, test_auroc: {out[1]}, test_acc: {out[2]}, test_prec: {out[3]}, test_rec: {out[4]}, test_f1: {2* ((out[3]*out[4]) / (out[3]+out[4]))}\n\" to results.txt ")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 2s 0us/step
# 171458560/171446536 [==============================] - 2s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/120
# 817/817 [==============================] - 998s 1s/step - loss: 0.7629 - auroc: 0.6956 - accuracy: 0.0010 - precision: 0.6385 - recall: 0.6385 - val_loss: 0.5247 - val_auroc: 0.8324 - val_accuracy: 0.0000e+00 - val_precision: 0.7688 - val_recall: 0.7688
#
# Epoch 00001: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00001: val_auroc improved from inf to 0.83243, saving model to models/ResNet101-13:09:2021, 15:31:50/best-ResNet101-13:09:2021, 15:31:50.hdf5
# Epoch 2/120
# 817/817 [==============================] - 938s 1s/step - loss: 0.5281 - auroc: 0.8144 - accuracy: 0.0000e+00 - precision: 0.7352 - recall: 0.7352 - val_loss: 1.5112 - val_auroc: 0.6159 - val_accuracy: 0.0440 - val_precision: 0.6000 - val_recall: 0.6000
#
# Epoch 00002: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00002: val_auroc improved from 0.83243 to 0.61588, saving model to models/ResNet101-13:09:2021, 15:31:50/best-ResNet101-13:09:2021, 15:31:50.hdf5
# Epoch 3/120
# 817/817 [==============================] - 954s 1s/step - loss: 0.4819 - auroc: 0.8499 - accuracy: 0.0000e+00 - precision: 0.7668 - recall: 0.7668 - val_loss: 0.8332 - val_auroc: 0.7132 - val_accuracy: 0.0028 - val_precision: 0.6600 - val_recall: 0.6600
#
# Epoch 00003: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00003: val_auroc did not improve from 0.61588
# Epoch 4/120
# 817/817 [==============================] - 960s 1s/step - loss: 0.4006 - auroc: 0.9006 - accuracy: 0.0000e+00 - precision: 0.8207 - recall: 0.8207 - val_loss: 0.6314 - val_auroc: 0.8378 - val_accuracy: 0.0000e+00 - val_precision: 0.7645 - val_recall: 0.7645
#
# Epoch 00004: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00004: val_auroc did not improve from 0.61588
# Epoch 5/120
# 817/817 [==============================] - 942s 1s/step - loss: 0.3243 - auroc: 0.9363 - accuracy: 0.0000e+00 - precision: 0.8629 - recall: 0.8629 - val_loss: 0.4314 - val_auroc: 0.9110 - val_accuracy: 7.6570e-04 - val_precision: 0.8386 - val_recall: 0.8386
#
# Epoch 00005: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00005: val_auroc did not improve from 0.61588
# Epoch 6/120
# 817/817 [==============================] - 943s 1s/step - loss: 0.2518 - auroc: 0.9615 - accuracy: 3.8288e-05 - precision: 0.8957 - recall: 0.8957 - val_loss: 0.4943 - val_auroc: 0.8687 - val_accuracy: 1.5314e-04 - val_precision: 0.7767 - val_recall: 0.7767
#
# Epoch 00006: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00006: val_auroc did not improve from 0.61588
# Epoch 7/120
# 817/817 [==============================] - 945s 1s/step - loss: 0.2046 - auroc: 0.9745 - accuracy: 0.0000e+00 - precision: 0.9159 - recall: 0.9159 - val_loss: 0.4068 - val_auroc: 0.9165 - val_accuracy: 0.0000e+00 - val_precision: 0.8309 - val_recall: 0.8309
#
# Epoch 00007: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00007: val_auroc did not improve from 0.61588
# Epoch 8/120
# 817/817 [==============================] - 965s 1s/step - loss: 0.1672 - auroc: 0.9826 - accuracy: 3.0630e-04 - precision: 0.9352 - recall: 0.9352 - val_loss: 0.5089 - val_auroc: 0.9215 - val_accuracy: 0.0074 - val_precision: 0.8603 - val_recall: 0.8603
#
# Epoch 00008: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00008: val_auroc did not improve from 0.61588
# Epoch 9/120
# 817/817 [==============================] - 958s 1s/step - loss: 0.1418 - auroc: 0.9870 - accuracy: 0.0023 - precision: 0.9469 - recall: 0.9469 - val_loss: 0.1848 - val_auroc: 0.9795 - val_accuracy: 7.6570e-04 - val_precision: 0.9338 - val_recall: 0.9338
#
# Epoch 00009: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00009: val_auroc did not improve from 0.61588
# Epoch 10/120
# 817/817 [==============================] - 957s 1s/step - loss: 0.1221 - auroc: 0.9904 - accuracy: 0.0020 - precision: 0.9533 - recall: 0.9533 - val_loss: 0.1687 - val_auroc: 0.9826 - val_accuracy: 0.0029 - val_precision: 0.9421 - val_recall: 0.9421
#
# Epoch 00010: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00010: val_auroc did not improve from 0.61588
# Epoch 11/120
# 817/817 [==============================] - 961s 1s/step - loss: 0.0975 - auroc: 0.9933 - accuracy: 0.0046 - precision: 0.9657 - recall: 0.9657 - val_loss: 0.1767 - val_auroc: 0.9832 - val_accuracy: 9.1884e-04 - val_precision: 0.9338 - val_recall: 0.9338
#
# Epoch 00011: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00011: val_auroc did not improve from 0.61588
# Epoch 12/120
# 817/817 [==============================] - 959s 1s/step - loss: 0.0876 - auroc: 0.9948 - accuracy: 0.0090 - precision: 0.9675 - recall: 0.9675 - val_loss: 0.2963 - val_auroc: 0.9609 - val_accuracy: 0.0015 - val_precision: 0.8989 - val_recall: 0.8989
#
# Epoch 00012: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00012: val_auroc did not improve from 0.61588
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.010000000149011612.
# Epoch 13/120
# 817/817 [==============================] - 964s 1s/step - loss: 0.0529 - auroc: 0.9979 - accuracy: 0.0182 - precision: 0.9812 - recall: 0.9812 - val_loss: 0.0691 - val_auroc: 0.9960 - val_accuracy: 0.0217 - val_precision: 0.9783 - val_recall: 0.9783
#
# Epoch 00013: saving model to models/ResNet101-13:09:2021, 15:31:50/latest-ResNet101-13:09:2021, 15:31:50.hdf5
#
# Epoch 00013: val_auroc did not improve from 0.61588
# Epoch 14/120
# 526/817 [==================>...........] - ETA: 5:15 - loss: 0.0409 - auroc: 0.9989 - accuracy: 0.0178 - precision: 0.9863 - recall: 0.9863

# %%
#Plot ROC
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
auc = auc(fpr, tpr)

plt.figure()
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
